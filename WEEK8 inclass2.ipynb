# %%
import pandas as pd
Location = "datasets/04-02 Confirmed.xls" 
df = pd.read_excel(Location)
df.columns = ['FIPS','Admin2','Province_State','Confirmed',]
print '\033[31;1m  Total global confirmed  \033[0m \n', '        ',df.at [0,'Confirmed']
df
# Out:
#   Total global confirmed
#          1013157
#          FIPS       Admin2  Province_State  Confirmed
# 0         0.0  Globe Total           Globe    1013157
# 1     45001.0    Abbeville  South Carolina          6
# 2     22001.0       Acadia       Louisiana         61
# 3     51001.0     Accomack        Virginia         10
# 4     16001.0          Ada           Idaho        312
# 5     19001.0        Adair            Iowa          1
# 6     29001.0        Adair        Missouri          6
# 7     40001.0        Adair        Oklahoma          9
# 8      8001.0        Adams        Colorado        212
# 9     16003.0        Adams           Idaho          1
# 10    17001.0        Adams        Illinois          2
# 11    18001.0        Adams         Indiana          1
# 12    28001.0        Adams     Mississippi         14
# 13    31001.0        Adams        Nebraska          6
# 14    42001.0        Adams    Pennsylvania         18
# 15    53001.0        Adams      Washington         20
# ...
